# %%
price = int(input("値段を入力してください: "))
tax = float(input("税率を入力してください: "))

def calculate_tax_included(price, tax):
     tax_included_price = price*(1+tax/100)
     print(tax_included_price)

calculate_tax_included(price,tax)
# Out:
# 値段を入力してください: 100
# 税率を入力してください: 5.0
# 105.0
