# %%
price = 110
tax = 10

def calculate_tax_included(price, tax):
     tax_included_price = price*(1+tax/100)
     return tax_included_price

tax_included_price = calculate_tax_included(price,tax)
print(tax_included_price)
# Out:
# 121.00000000000001
