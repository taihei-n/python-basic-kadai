# %%
array = ["水","金","地","火","木","土","天","海","冥"]

for value in array:
    print(value)
n=0
while n < 9:
    print(array[n])
    n=n+1
# Out:
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
